# %% [markdown]
# # Fusion Tests
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/your-org/ai-multi-reference-timekeeping/blob/main/notebooks/10_test_fusion.ipynb)
#
# Runs the fusion test suite to validate heuristic fusion and quality weighting.

# %%
import os
if not os.path.exists('ai-multi-reference-timekeeping'):
    # !git clone https://github.com/your-org/ai-multi-reference-timekeeping.git
# %cd ai-multi-reference-timekeeping
# !pip install -e .

# %%
# !python -m pytest tests/test_fusion.py -q
